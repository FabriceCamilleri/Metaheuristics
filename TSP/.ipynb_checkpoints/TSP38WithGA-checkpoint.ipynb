# %% [markdown]
# # Traveling Salesman Problem with 38 cities
#
# ## Choice of the algorithm
# <hr><hr>
#
# A Genetic Algorithm as it is suited for discrete optimization
#
# ## Getting the data
# <hr><hr>

# %%
import imp
imp.reload(GA.GA)
from GA.GA import *

# %%
# we create a pandas dataframe from the file containing the coordinates of the cities
cities=pd.read_csv("dj38.tsp", skiprows=10, header=None, delimiter=' ')
# we create an list of City object (see city object definition in GA/GA.py)
cities=[City (x[0], x[1]) for x in np.array(cities.loc[:,1:]) ]

# %%
# First route taking the cities in the order
showMap(cities)
print ('Distance: ' +str(1 / Fitness(cities).routeFitness()))
# Out:
# Distance: 17099.017153650082

# %% [markdown]
# ## Finding the right parameters
# <hr><hr>
#
# To find the right parameter, let's test for a given parameter different values and choose the best one.
# To do so, let's consider the fitness values of 50 runs.
#
# ### Mutation rate
# The mutation step allows to explore the search space.
# If the mutation rate is too high, it will not allow exploitation, meaning finding a local minimum, which can be the global minimum.
# If the the mutation rate is too low, it will allow exploration of the search space.
# Let's try different mutations rates, keeping the other parameters constant, to decide which rate we should use.

# %%
finalDistanceList = []
for i in range(0,50):
    finalDistance = geneticAlgorithm(population=cities, popSize=100, eliteSize=10, mutationRate=0.01, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
finalDistanceList=np.array(finalDistanceList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
# Out:
# Max Final Distance:13536.710272995733
# Min Final Distance:9174.998604404045
# Mean Final Distance:11514.71807311817
# STD Final Distance:1005.0427224522083

# %%
finalDistanceList = []
for i in range(0,50):
    finalDistance = geneticAlgorithm(population=cities, popSize=100, eliteSize=10, mutationRate=0.005, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
finalDistanceList=np.array(finalDistanceList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
# Out:
# Max Final Distance:14450.65039334231
# Min Final Distance:8359.651543045085
# Mean Final Distance:10481.719242353447
# STD Final Distance:1227.3530094972248

# %%
finalDistanceList = []
for i in range(0,50):
    finalDistance = geneticAlgorithm(population=cities, popSize=100, eliteSize=10, mutationRate=0.001, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
finalDistanceList=np.array(finalDistanceList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
# Out:
# Max Final Distance:13412.482920340686
# Min Final Distance:8251.749744948385
# Mean Final Distance:10137.72356489602
# STD Final Distance:1093.3126849870016

# %% [markdown]
# **Conclusion**
#
# A mutation rate of 0.001 gives better result, we will keep this rate from now on.

# %% [markdown]
# ### Elite size
#
# The selection of the parents for the cross-over is done by
# - keeping the N fittest individuals
# - for the remaining par of the selection, the parent are randomly selected, with a higher change for the fittest individuals (Roulette Wheel Selection).
#
# Let's see how the size of the elite influences the best distance.

# %%
finalDistanceList = []
for i in range(0,50):
    finalDistance = geneticAlgorithm(population=cities, popSize=100, eliteSize=10, mutationRate=0.001, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
finalDistanceList=np.array(finalDistanceList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
# Out:
# Max Final Distance:12841.562086126261
# Min Final Distance:7454.872603026122
# Mean Final Distance:10079.590283241205
# STD Final Distance:1174.7062396226004

# %%
finalDistanceList = []
for i in range(0,50):
    finalDistance = geneticAlgorithm(population=cities, popSize=100, eliteSize=20, mutationRate=0.001, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
finalDistanceList=np.array(finalDistanceList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
# Out:
# Max Final Distance:10542.785213184165
# Min Final Distance:7109.813104274781
# Mean Final Distance:8918.814688311362
# STD Final Distance:864.3809800746424

# %%
finalDistanceList = []
for i in range(0,50):
    finalDistance = geneticAlgorithm(population=cities, popSize=100, eliteSize=30, mutationRate=0.001, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
finalDistanceList=np.array(finalDistanceList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
# Out:
# Max Final Distance:11756.494689660183
# Min Final Distance:7127.427203635906
# Mean Final Distance:8687.92255791169
# STD Final Distance:901.1908416382695

# %%
finalDistanceList = []
for i in range(0,50):
    finalDistance = geneticAlgorithm(population=cities, popSize=100, eliteSize=50, mutationRate=0.001, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
finalDistanceList=np.array(finalDistanceList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
# Out:
# Max Final Distance:13170.377651507733
# Min Final Distance:7087.984079650614
# Mean Final Distance:9153.609928791695
# STD Final Distance:1336.2439336424095

# %% [markdown]
# **Conclusion**
#
# A ratio a 30% gives the best result. Let's keep this ratio from now on.

# %% [markdown]
# ### Population size
#
# The higher the population, the bigger is the space is, but also the higher the computational time is.
# Let's try different values to find the best trade-off.

# %%
finalDistanceList = []
timeList = []
for i in range(0,10):
    finalDistance = geneticAlgorithm(population=cities, popSize=100, eliteSize=30, mutationRate=0.001, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
    timeList.append(finalDistance[3])
finalDistanceList=np.array(finalDistanceList)
timeList=np.array(timeList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
print ('Mean execution time:' + str(timeList.mean()) )
# Out:
# Max Final Distance:9350.34015304933
# Min Final Distance:7813.7734981601325
# Mean Final Distance:8909.665027758248
# STD Final Distance:444.2930032114586
# Mean execution time:7.239039897918701

# %%
finalDistanceList = []
timeList = []
for i in range(0,10):
    finalDistance = geneticAlgorithm(population=cities, popSize=200, eliteSize=30, mutationRate=0.001, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
    timeList.append(finalDistance[3])
finalDistanceList=np.array(finalDistanceList)
timeList=np.array(timeList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
print ('Mean execution time:' + str(timeList.mean()) )
# Out:
# Max Final Distance:9432.925842911
# Min Final Distance:6902.366525969501
# Mean Final Distance:8056.770180974153
# STD Final Distance:764.8277128102992
# Mean execution time:27.35349476337433

# %%
finalDistanceList = []
timeList = []
for i in range(0,10):
    finalDistance = geneticAlgorithm(population=cities, popSize=300, eliteSize=30, mutationRate=0.001, N=20, plot=False)
    finalDistanceList.append(finalDistance[0])
    timeList.append(finalDistance[3])
finalDistanceList=np.array(finalDistanceList)
timeList=np.array(timeList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
print ('Mean execution time:' + str(timeList.mean()) )
# Out:
# Max Final Distance:8227.311237337864
# Min Final Distance:6975.241616815662
# Mean Final Distance:7601.529678908742
# STD Final Distance:379.8306352881533
# Mean execution time:61.4178769826889

# %% [markdown]
# **Conclusion**
#
# For a population size of 300 it takes about 1 min to compute the algorithm.
#
# Another paramater that will also impact the computation time is the stopping criterion.

# %% [markdown]
# ### Stopping criterion
#
# The algorithm stops when the fitness value has almost not changed over the last N generations.
# We expect here to have a better final distance when N is big.
# Let's try different values.

# %%
finalDistanceList = []
timeList = []
for i in range(0,10):
    finalDistance = geneticAlgorithm(population=cities, popSize=300, eliteSize=30, mutationRate=0.001, N=10, plot=False)
    finalDistanceList.append(finalDistance[0])
    timeList.append(finalDistance[3])
finalDistanceList=np.array(finalDistanceList)
timeList=np.array(timeList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
print ('Mean execution time:' + str(timeList.mean()) )
# Out:
# Max Final Distance:12929.085761801847
# Min Final Distance:9085.759695294502
# Mean Final Distance:10163.548965406077
# STD Final Distance:1179.3103004467569
# Mean execution time:22.846266126632692

# %%
finalDistanceList = []
timeList = []
for i in range(0,10):
    finalDistance = geneticAlgorithm(population=cities, popSize=300, eliteSize=30, mutationRate=0.001, N=30, plot=False)
    finalDistanceList.append(finalDistance[0])
    timeList.append(finalDistance[3])
finalDistanceList=np.array(finalDistanceList)
timeList=np.array(timeList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
print ('Mean execution time:' + str(timeList.mean()) )
# Out:
# Max Final Distance:8136.520239004713
# Min Final Distance:6659.431532931463
# Mean Final Distance:7340.858838144038
# STD Final Distance:445.74406541682225
# Mean execution time:86.2424354314804

# %%
finalDistanceList = []
timeList = []
for i in range(0,10):
    finalDistance = geneticAlgorithm(population=cities, popSize=300, eliteSize=30, mutationRate=0.001, N=40, plot=False)
    finalDistanceList.append(finalDistance[0])
    timeList.append(finalDistance[3])
finalDistanceList=np.array(finalDistanceList)
timeList=np.array(timeList)
print ('Max Final Distance:' + str(finalDistanceList.max())) 
print ('Min Final Distance:' + str(finalDistanceList.min()) )
print ('Mean Final Distance:' + str(finalDistanceList.mean()) )
print ('STD Final Distance:' + str (finalDistanceList.std() ))
print ('Mean execution time:' + str(timeList.mean()) )
# Out:
# Max Final Distance:7734.290730306048
# Min Final Distance:6748.248029788878
# Mean Final Distance:7156.572083126329
# STD Final Distance:344.9697961621375
# Mean execution time:95.49493594169617

# %% [markdown]
# ## Finding the best solution
# <hr><hr>
# Now that we have found the right parameters, let's run the algorithm a last time and display the best solution.

# %%
finalDistance = geneticAlgorithm(population=cities, popSize=300, eliteSize=80, mutationRate=0.001, N=40)

# %%
showMap(finalDistance[2])
print ("Final fitness: " + str(finalDistance[0]))
print ("Number of function evaluations: " + str(finalDistance[1]))
print ("Computational time : " + str(finalDistance[3]))
print ("Number of generations : " + str(finalDistance[4]))
# Out:
# Final fitness: 6723.26206420125
# Number of function evaluations: 132600
# Computational time : 39.23107862472534
# Number of generations : 220
