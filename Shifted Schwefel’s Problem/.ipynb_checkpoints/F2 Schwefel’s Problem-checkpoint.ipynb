# %% [markdown]
# #  F2: Schwefel’s Problem
#
# Minimum at -450

# %%
import sys
sys.path.append('../')
from functions import *
from PSO import *
import numpy as np
import matplotlib.pyplot as plt

# %%
plot_fct(Schwefel_Problem)

# %%
class F2_Schwefel_Problem:
    
    nbFitness = 0
    
    def __init__(self, dim, bounds):
        self.dim = dim
        self.bounds=bounds

    def fitness(self, x):
        F = abs(x[0])
        for i in range(0,x.shape[0]):
            z = x[i] - schwefel[i]
            F = np.maximum(F , abs(z))
        return [F + f_bias[1]]

    def get_bounds(self):
        return ([-100] * self.dim, [100] * self.dim)
    
    def get_name(self):
        return "F2: Schwefel Problem "

    def get_extra_info(self):
        return "\tDimensions: " + str(self.dim)

# %%
prob = pg.problem(F2_Schwefel_Problem(50))

# %% [markdown]
# PSO Algo
# - size: normally 10 to 60.
# - inertia factor normally form 0.4 to 1.4
# - sefl confidence normally from 1.5 to 2
# - swarm confidence normally from 2 to 2.5
#
# gen (int) – number of generations
# omega (float) – inertia weight (or constriction factor)
# eta1 (float) – social component
# eta2 (float) – cognitive component
#
# Intensification
# Diversification
#
# Here no local minimum so we should intensify.
#
# Meaning

# %%
algo = pg.algorithm(pg.pso(gen = 500, omega=0.4,eta1=1.1, eta2=2.5, variant = 5))
algo.set_verbosity(1)
pop = pg.population(prob,40)
pop = algo.evolve(pop)
uda = algo.extract(pg.pso)
log=np.array(uda.get_log() )
pop.get_f()[pop.best_idx()]
# Out:
# array([-367.06078098])

# %%
plt.plot(log[:,0],log[:,2])
plt.show()

# %%
Shifted_Sphere(np.array([sphere[0:3]]))
# Out:
# array([-450.])

# %%
pop.get_f()[pop.best_idx()]
# Out:
# array([-45.7832106])

# %%
pop
# Out:
# Problem name: F1: Shifted_Sphere function
# 	Global dimension:			500
# 	Integer dimension:			0
# 	Fitness dimension:			1
# 	Number of objectives:			1
# 	Equality constraints dimension:		0
# 	Inequality constraints dimension:	0
# 	Lower bounds: [-100, -100, -100, -100, -100, ... ]
# 	Upper bounds: [100, 100, 100, 100, 100, ... ]
# 	Has batch fitness evaluation: false
#
# 	Has gradient: false
# 	User implemented gradient sparsity: false
# 	Has hessians: false
# 	User implemented hessians sparsity: false
#
# 	Fitness evaluations: 750500
#
# 	Thread safety: none
#
# Extra info:
# 	Dimensions: 500
# Population size: 500
#
# List of individuals:
# #0:
# 	ID:			13920910371742276794
# 	Decision vector:	[95.1547, 74.2192, -19.2345, 25.0413, -19.837, ... ]
# 	Fitness vector:		[3683.9]
# #1:
# 	ID:			11517876442224749638
# 	Decision vector:	[95.0457, 74.2156, -19.1942, 25.0191, -19.8429, ... ]
# 	Fitness vector:		[3652.33]
# #2:
# 	ID:			7008232304782871151
# ...
